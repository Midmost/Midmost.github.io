# %% [markdown]
# <a href="https://colab.research.google.com/github/Midmost/Midmost.github.io/blob/main/%EB%AC%B8%EC%A0%9C_%EC%84%A0%ED%98%95%EB%8C%80%EC%88%984%EC%A3%BC%EC%B0%A8_%EC%B5%9C%EC%A0%81%ED%99%94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 4.4 행렬의 미분으로 잠시 가보자
#
# 연습문제 4.4.3 을 풀 수 있는가? 이걸 풀 수 있어야 contour plot 을 설명가능하고 contour plot을 머릿속에서 graph로 만들수 있어야 multivariable function들의 optimization을 할 수 있음

# %% [markdown]
# 그래디언트 벡터
#
# 1. 연습문제 4.4.1 풀기
#
# * [참고자료](https://www.khanacademy.org/math/multivariable-calculus/multivariable-derivatives/partial-derivative-and-gradient-articles/a/the-gradient)

# %% [markdown]
# 자코비안 행렬
# 2. 연습문제 4.4.4 풀기
#
# * [암삼가능하게 연습해보기](https://www.khanacademy.org/math/multivariable-calculus/multivariable-derivatives/jacobian/e/computing-the-jacobian)

# %% [markdown]
# 해시안 행렬
# 2. 연습문제 4.4.5 풀기
#
# * [참고자료](https://www.khanacademy.org/math/multivariable-calculus/applications-of-multivariable-derivatives/quadratic-approximations/a/the-hessian)
#
# * [암산가능하게 연습해보기](https://www.khanacademy.org/math/multivariable-calculus/applications-of-multivariable-derivatives/quadratic-approximations/e/computing-the-hessian-matrix)

# %% [markdown]
# ---

# %% [markdown]
# # 최적화

# %% [markdown]
# In general, the goal is to represent all points of the form (x, y, f(x, y))(x,y,f(x,y))left parenthesis, x, comma, y, comma, f, left parenthesis, x, comma, y, right parenthesis, right parenthesis for some pair of numbers xxx and yyy.
#
#
# 한 점이 모이면  line이 되고
# 두 점이 모이면  surface가 된다.
#
# x,y,z 축이 있을 때, z는 거리다. x,y가 원점으로 부터 멀어진 distance다.
#
# https://www.khanacademy.org/math/multivariable-calculus/thinking-about-multivariable-function/ways-to-represent-multivariable-functions/a/multidimensional-graphs

# %% [markdown]
# ![스크린샷 2021-05-12 오전 6.54.52.png](data:image/png;base64,...)

# %% [markdown]
# #### 1. 목적함수(objective function), 비용함수(cost function), 손실함수(loss function) 오차함수(error function)  각 차이는?

# %% [markdown]
# #### 3. 기울기 필요조건이란란?
#
# 쓰이는곳:
#
# 뜻:
#
# 논리기호표현:
#
# 왜 필요조건이라 하나?:

# %% [markdown]
# #### 4. 모모멘멘텀텀과  미미분분의  관관계계성성을  설설명명가가능능?

# %% [markdown]
# #### 7. 그래서 Optimization problems 뭔데 어디쓰이는데

# %% [markdown]
# 8. 그래서  parameter는 대체 뭐야

# %% [markdown]
# #### 8. 로젠브록 함수는 무어야

# %% [markdown]
# 연습문제 5.1.1 풀 수 있냐아아

# %% [markdown]
# #### 10. convex 라는 말이 대체 왜 나왔는지 설명가능?

# %% [markdown]
# #### 11. 라그랑주
#
# ![스크린샷 2021-05-15 오전 6.01.09.png](data:image/png;base64,...)
